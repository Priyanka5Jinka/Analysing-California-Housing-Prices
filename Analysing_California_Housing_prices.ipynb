# %% [markdown]
# # **Project : Analysing California Housing Prices using Python**

# %% [markdown]
# ## Dataset : 'housing.xlsx'

# %% [markdown]
# *Introduction:*

# %% [markdown]
# *   The data contains information from the 1990 California census.
#
# *   The data pertains to the houses found in a given California district and
#     some summary stats about them based on the 1990 census data.
#
# *   The columns are as follows:
#
#   1. *longitude:* A measure of how far west a house is; a higher value is farther west
#   2. *latitude:* A measure of how far north a house is; a higher value is farther north
#   3. *housingMedianAge:* Median age of a house within a block; a lower number is a newer building
#   4. *totalRooms:* Total number of rooms within a block
#   5. *totalBedrooms:* Total number of bedrooms within a block
#   6. *population:* Total number of people residing within a block
#   7. *households:* Total number of households, a group of people residing within a home unit, for a block
#   8. *medianIncome:* Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#   9. *medianHouseValue:* Median house value for households within a block (measured in US Dollars)
#   10. *oceanProximity:* Location of the house w.r.t ocean/sea

# %% [markdown]
# Types of Data :
#
#
#
# *   Categorial/Qualitative Data:
#
#   1.   Nominal
#   2.   Ordinal
#
# *   Quantitative Data:
#
#   1.   Dicrete
#   2.   Continuous
#
#
#
# *   **Nominal Data:** Nominal Data is used to label variables without any order. With the help of nominal data, we can't do any numerical tasks or can't give any order to sort the data.
# *   **Ordinal Data:** Ordinal data have natural ordering where a number is present in some kind of order by their position on the scale. These data are used for observation but we can't do any arithmetical tasks on them.
# *   **Discrete Data:** The discrete data contain the values that fall under integers or whole numbers.These data can't be broken into decimal or fraction values.
# *   **Continuous Data:** Continuous data are in the form of fractional numbers.
#
#
# ---
#
#
# *Features of the data categorised:*
#
# *   longitude - Continuous
# *   latitude - Continuous
# *   housing_median_age - Discrete
# *   total_rooms - Discrete
# *   total_bedrooms - Discrete
# *   population - Discrete
# *   households - Discrete
# *   median_income - Continuous
# *   median_house_value - Discrete
# *   ocean_proximity - Nominal

# %%
#uploading file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-81a96cc5-83f0-4d40-bf83-4c1069a594a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81a96cc5-83f0-4d40-bf83-4c1069a594a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#importing libraries needed

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading excel file into pandas dataframe
housing = pd.read_excel('housing.xlsx')
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
#to check for number of rows and columns
housing.shape
# Out:
# (20640, 10)

# %%
#checking for the information of the dataset
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
#checking for statistical observation of the dataframe
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#having a look at the dataset columns
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
#calculating average of median income using mean() method
average = housing.median_income.mean()
average
# Out:
# 3.8706710029069766

# %%
#creating a histogram for the column median income
plt.hist(housing.median_income,bins = 15,edgecolor = 'black',color = 'skyblue')

#creating values for fontdict for title and labels
f1 = {'color':'red','size':15}
f2 = {'color':'green','size':12}

#creating title and labels
plt.xlabel('Median Income',fontdict=f2)
plt.ylabel('Frequency',fontdict=f2)
plt.title('Distribution of Median Income',fontdict=f1)

plt.show()

# %% [markdown]
# From the above plot,we can observe that whose median income is in the range of 3(tens of thousands of US dollars) has the highest frequency i.e districts with income 3(tens of thousands of US dollars) are around 5500 and the 2nd highest is median income is in the range of 4(tens of thousands of US dollars).They are around 4500.

# %%
# or using histogram plot of seaborn library

sns.histplot(housing.median_income,bins = 20,edgecolor = 'black',color = 'skyblue',kde=True)
plt.xlabel('Median Income')
plt.ylabel('Frequency')
plt.title('Distribution of Median Income')
plt.show()

# %% [markdown]
# 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
#creating a histogram plot to check the distribution of housing median age
plt.hist(housing.housing_median_age, bins = 15,color = 'orange',edgecolor='red')

#creating values for fontdict for title and labels
f1 = {'color':'green','size':15}
f2 = {'color':'brown','size':12}

#creating title and labels
plt.xlabel('Median Age of a house',fontdict=f2)
plt.ylabel('Frequency',fontdict=f2)
plt.title('Distribution of Median age of a house',fontdict=f1)

plt.show()

# %% [markdown]
# From the above plot,we can say that -
# There are around 2600 districts, when the median age of a house is between 35-40. This is the highest.

# %% [markdown]
# 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
#creating scatter plot between median income and median house value
plt.scatter(housing.median_income,housing.median_house_value,alpha=0.5,facecolor='green',edgecolor='pink',s=40)

#creating values for fontdict for title and labels
f1 = {'color':'Red','size':15}
f2 = {'color':'blue','size':12}

#creating title and labels
plt.xlabel('Median Income',fontdict = f2)
plt.ylabel('Median house value',fontdict = f2)
plt.title('Relationship between Median Income and Median House Value',fontdict = f1)

plt.show()

# %% [markdown]
# We can say that,as the median income values increases, median house value also increases. As the points are moving from bottom left to top right, there is a positive relationship between the two.
# Since the points are packed,when can say the two parameters has strong relationship.

# %% [markdown]
# 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
#checking for total no. of null values present in total_bedrooms column
housing.total_bedrooms.isnull().sum()
# Out:
# 207

# %%
#removing rows where the null values are present in total_bedrooms column by .dropna()method with parameter as subset for chosing column
housing_new = housing.dropna(subset=['total_bedrooms'])
housing_new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#confirming the total null values in the column total_bedrooms
housing_new.total_bedrooms.isnull().sum()
# Out:
# 0

# %% [markdown]
# 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
#checking for total no. of null values present in total_bedrooms column
housing.total_bedrooms.isnull().sum()
# Out:
# 207

# %%
#finding the mean value of the column total_bedrooms
mean_val = housing.total_bedrooms.mean()

#filling the missing data with the mean value using .fillna() method
housing.total_bedrooms.fillna(mean_val,inplace = True)
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#confirming the total null values in the column total_bedrooms
housing.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
#creating a function for calculating mean of a particular column
def median_calculation(housing, column_name):

  #selecting a specified column and calculating median
  median_value = housing[column_name].median()

  return median_value

#taking column name input from user
column_name = input('Enter the column name on which you want to calculate median value: ')

#calling the user defined function to calculate the median of particular column
median_income = median_calculation(housing,column_name)
print('Median value: ',median_income)
# Out:
# Enter the column name on which you want to calculate median value: households
# Median value:  409.0

# %% [markdown]
# 7. Plot latitude versus longitude and explain your observations.

# %%
#creating a scatter plot for the latitude and longitude columns
plt.scatter(housing.latitude, housing.longitude,alpha = 0.5,facecolor = 'cyan',edgecolor = 'k')

#creating values for fontdict for title and labels
f1 = {'color':'Red','size':15}
f2 = {'color':'blue','size':12}

#creating title and labels
plt.xlabel('Latitude',fontdict = f2)
plt.ylabel('Longitude',fontdict = f2)
plt.title('Latitude vs Longitude',fontdict = f1)

plt.show()

# %% [markdown]
# 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
#checking for the unique values in column 'occean_proximity'
housing.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
#checking for the values where values in the column 'ocean_proximity' is 'near ocean' or not and creating a new dataset and storing the values in that.
near_ocean_ds = housing[housing['ocean_proximity'] == 'NEAR OCEAN']
near_ocean_ds.head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850    -124.17     41.80                  16         2739           480.0
# 1851    -124.30     41.80                  19         2672           552.0
# 1852    -124.23     41.75                  11         3159           616.0
# 1853    -124.21     41.77                  17         3461           722.0
# 1854    -124.19     41.78                  15         3140           714.0
#
#       population  households  median_income  median_house_value  \
# 1850        1259         436         3.7557              109400
# 1851        1298         478         1.9797               85800
# 1852        1343         479         2.4805               73200
# 1853        1947         647         2.5795               68400
# 1854        1645         640         1.6654               74600
#
#      ocean_proximity
# 1850      NEAR OCEAN
# 1851      NEAR OCEAN
# 1852      NEAR OCEAN
# 1853      NEAR OCEAN
# ...

# %%
#confirming the values in the column 'ocean_proximity'
near_ocean_ds.ocean_proximity.unique()
# Out:
# array(['NEAR OCEAN'], dtype=object)

# %% [markdown]
# 9. Find the mean and median of the median income for the data set created in question 8.

# %%
#calculating the mean and median income for the dataset where ocean proximity is near ocean using mean() and median() methods
mean = near_ocean_ds['median_income'].mean()
median = near_ocean_ds['median_income'].median()

print('The mean of the median income where ocean proximity is near ocean is: ',mean)
print('The median of the median income where ocean proximity is near ocean is: ',median)
# Out:
# The mean of the median income where ocean proximity is near ocean is:  4.0057848006019565
# The median of the median income where ocean proximity is near ocean is:  3.64705

# %% [markdown]
# 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
#creating a new column total bedroom size by assigning it with None value
housing['total_bedroom_size'] = None

#using enumerate function to create index values for the column total bedrooms and checking the conditions
for k,v in enumerate(housing['total_bedrooms']):
  if v<=10:
    housing.total_bedroom_size[k] = 'small'
  elif v>=11 and v<1000:
    housing.total_bedroom_size[k] = 'medium'
  else:
    housing.total_bedroom_size[k] = 'large'

housing.head()
# Out:
# <ipython-input-51-57936fc2e32a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing.total_bedroom_size[k] = 'medium'
# <ipython-input-51-57936fc2e32a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing.total_bedroom_size[k] = 'large'
# <ipython-input-51-57936fc2e32a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing.total_bedroom_size[k] = 'small'
# ...
